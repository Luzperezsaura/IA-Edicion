# %% [markdown]
# # **Prueba 3 de entrenamiento de red neuronal**
# Entrenamiento de red neuronal (YOLO_v8) para la detección de ojalillos y automatización de la edición de estudios
# Se cambia el parámetro `fliplr=0.0` para que no espeje las imagenes de la base de datos.

# %%
# Instalamos la librería oficial de YOLO
# !pip install -q ultralytics

# Verificamos que PyTorch esté detectando la GPU correctamente
import torch
if torch.cuda.is_available():
    print(f"¡Excelente! GPU detectada: {torch.cuda.get_device_name(0)}")
else:
    print("ERROR: No se detectó GPU. Revisa el Paso 2.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.4 MB/s eta 0:00:00
# ¡Excelente! GPU detectada: Tesla T4

# %%
# Descomprimimos el archivo zip de forma silenciosa (-q)
# !unzip -q /content/dataset_biomecanica-2.zip -d /content/

# %%
import yaml

# Estructura de puntos (pi1, pi2, ti1, ti2) = 4 keypoints
data = {
    'path': '/content/dataset_biomecanica', # Ruta base absoluta en Colab
    'train': 'images/train',
    'val': 'images/val',
    'names': {0: 'zona_piernas'},
    'kpt_shape': [4, 3] # 4 keypoints, 3 dimensiones (x, y, visibilidad)
}

# Guardamos el archivo
with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f)

print("Archivo data.yaml creado correctamente.")
# Out:
# Archivo data.yaml creado correctamente.

# %%
# !yolo pose train data=/content/data.yaml model=yolov8m-pose.pt epochs=150 imgsz=1024 batch=8 project=biomecanica name=modelo_izq_v1 device=0 fliplr=0.0
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m-pose.pt to 'yolov8m-pose.pt': 100% ━━━━━━━━━━━━ 50.8MB 121.3MB/s 0.4s
# Ultralytics 8.4.50 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=modelo_izq_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=biomecanica, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/pose/biomecanica/modelo_izq_v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.3MB/s 0.0s
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   4338487  ultralytics.nn.modules.head.Pose             [1, [4, 3], 16, None, [192, 384, 576]]
# YOLOv8m-pose summary: 185 layers, 26,419,111 parameters, 26,419,095 gradients, 81.2 GFLOPs
#
# Transferred 481/517 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 105.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2556.6±1588.2 MB/s, size: 488.6 KB)
# train: Scanning /content/dataset_biomecanica/labels/train... 31 images, 0 backgrounds, 20 corrupt: 100% ━━━━━━━━━━━━ 51/51 132.3it/s 0.4s
# train: /content/dataset_biomecanica/images/train/i0108715.png: ignoring corrupt image/label: image file is truncated (66 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0110952.png: ignoring corrupt image/label: image file is truncated (86 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0110973.png: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111016.png: ignoring corrupt image/label: image file is truncated (53 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111049.png: ignoring corrupt image/label: image file is truncated (61 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111067.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111079.png: ignoring corrupt image/label: image file is truncated (75 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111091.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111106.png: ignoring corrupt image/label: image file is truncated (28 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111158.png: ignoring corrupt image/label: image file is truncated (59 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111194.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111225.png: ignoring corrupt image/label: image file is truncated (61 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111240.png: ignoring corrupt image/label: image file is truncated (86 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111270.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111285.png: ignoring corrupt image/label: image file is truncated (53 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111303.png: ignoring corrupt image/label: image file is truncated (72 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111313.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111332.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111348.png: ignoring corrupt image/label: image file is truncated (47 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111359.png: ignoring corrupt image/label: image file is truncated (27 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111379.png: corrupt JPEG restored and saved
# train: /content/dataset_biomecanica/images/train/i0111393.png: ignoring corrupt image/label: image file is truncated (55 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111416.png: ignoring corrupt image/label: image file is truncated (48 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111427.png: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111441.png: ignoring corrupt image/label: image file is truncated (68 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111461.png: ignoring corrupt image/label: image file is truncated (20 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111478.png: ignoring corrupt image/label: image file is truncated (55 bytes not processed)
# train: /content/dataset_biomecanica/images/train/i0111497.png: corrupt JPEG restored and saved
# train: New cache created: /content/dataset_biomecanica/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 
0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     126/150      8.47G     0.5593    0.09737     0.1074     0.4176      1.031         13       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.873      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     127/150      8.49G     0.5266    0.05863     0.1368     0.3893     0.9822         11       1024: 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.866      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     128/150      8.49G     0.6625    0.06792     0.1105     0.4617      1.142         20       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.866      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     129/150      8.49G     0.5265    0.06197     0.1362     0.4028      1.053         13       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7it/s 0.4s
#                    all         11         11      0.995          1      0.995      0.863      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     130/150      8.48G     0.5312    0.08165     0.1371     0.4026      1.048         15       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.863      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     131/150      8.49G     0.5257    0.05342    0.09393      0.384      1.022         14       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.886      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     132/150      8.47G     0.5472    0.08005     0.1064     0.4121      1.049         16       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.886      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     133/150      8.49G      0.469    0.05747    0.07425      0.357     0.9493         11       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.995          1      0.995       0.88      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     134/150       8.5G     0.4962      0.062    0.09866      0.371     0.9769         14       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         11         11      0.995          1      0.995       0.88      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     135/150      8.48G     0.5356    0.07885    0.09435     0.3803     0.9952         17       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.877      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     136/150      8.48G     0.4723    0.06151    0.08039     0.3774      1.006         12       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.877      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     137/150      8.48G     0.4706    0.07159     0.1809     0.3582      1.044         12       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.995          1      0.995       0.87      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     138/150      8.47G     0.5495    0.05479     0.1137       0.43     0.9977         11       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.4s
#                    all         11         11      0.995          1      0.995       0.87      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     139/150      8.48G     0.4686    0.06498        0.1     0.3312     0.9487         15       1024: 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.877      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     140/150      8.49G     0.4024    0.03975    0.03602     0.3179     0.9364         18       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.877      0.995          1      0.995      0.995
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     141/150      8.49G     0.3954    0.04272     0.0136     0.3178     0.9447          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.865      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     142/150      8.48G     0.3771    0.04089    0.01348      0.302     0.9281          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.865      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     143/150      8.47G     0.4251    0.04591    0.01685     0.3076       1.01          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.875      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     144/150      8.47G      0.402    0.04721     0.0183      0.311      0.982          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.875      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     145/150      8.48G     0.4497    0.05084    0.01707     0.3204     0.9904          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all         11         11      0.995          1      0.995      0.875      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     146/150      8.48G     0.3706    0.05293    0.01636     0.3063     0.9248          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all         11         11      0.995          1      0.995      0.875      0.995          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     147/150      8.47G     0.3747    0.04314    0.01304     0.2702     0.9409          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.994          1      0.995      0.876      0.994          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     148/150      8.48G     0.3496    0.03408    0.01431     0.2898     0.9085          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all         11         11      0.994          1      0.995      0.876      0.994          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     149/150      8.46G     0.3659    0.04235    0.01717     0.2834     0.8829          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.3it/s 0.3s
#                    all         11         11      0.993          1      0.995      0.875      0.993          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     150/150      8.46G     0.3513     0.0346    0.01646      0.286     0.9585          7       1024: 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.993          1      0.995      0.875      0.993          1      0.995      0.995
#
# 150 epochs completed in 0.296 hours.
# Optimizer stripped from /content/runs/pose/biomecanica/modelo_izq_v1/weights/last.pt, 53.2MB
# Optimizer stripped from /content/runs/pose/biomecanica/modelo_izq_v1/weights/best.pt, 53.2MB
#
# Validating /content/runs/pose/biomecanica/modelo_izq_v1/weights/best.pt...
# Ultralytics 8.4.50 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8m-pose summary (fused): 102 layers, 26,402,263 parameters, 0 gradients, 80.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all         11         11      0.995          1      0.995       0.91      0.995          1      0.995      0.995
# Speed: 0.3ms preprocess, 20.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/runs/pose/biomecanica/modelo_izq_v1
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
from google.colab import files

# Nueva ruta basada en nuestro último comando (modelo_v3)
ruta_modelo = '/content/runs/pose/biomecanica/modelo_izq_v1/weights/best.pt'

files.download(ruta_modelo)
