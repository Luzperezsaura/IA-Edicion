# %% [markdown]
# # **Prueba 1 de entrenamiento de red neuronal**
# Entrenamiento de red neuronal (YOLO_v8) para la detección de ojalillos y automatización de la edición de estudios

# %%
# Instalamos la librería oficial de YOLO
# !pip install -q ultralytics

# Verificamos que PyTorch esté detectando la GPU correctamente
import torch
if torch.cuda.is_available():
    print(f"¡Excelente! GPU detectada: {torch.cuda.get_device_name(0)}")
else:
    print("ERROR: No se detectó GPU. Revisa el Paso 2.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.9 MB/s eta 0:00:00
# ¡Excelente! GPU detectada: Tesla T4

# %%
# Descomprimimos el archivo zip de forma silenciosa (-q)
# !unzip -q /content/dataset_biomecanica.zip -d /content/
print("Dataset descomprimido exitosamente.")
# Out:
# Dataset descomprimido exitosamente.

# %% [markdown]
# Creo archivo de configuración:

# %%
import yaml

# Estructura de puntos (pi1, pi2, ti1, ti2) = 4 keypoints
data = {
    'path': '/content/dataset_biomecanica', # Ruta base absoluta en Colab
    'train': 'images/train',
    'val': 'images/val',
    'names': {0: 'zona_piernas'},
    'kpt_shape': [4, 3] # 4 keypoints, 3 dimensiones (x, y, visibilidad)
}

# Guardamos el archivo
with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f)

print("Archivo data.yaml creado correctamente.")
# Out:
# Archivo data.yaml creado correctamente.

# %% [markdown]
# ### **Entrenamiento**

# %%
# Ejecutamos el entrenamiento por consola (CLI) de Ultralytics
# !yolo pose train data=/content/data.yaml model=yolov8n-pose.pt epochs=100 imgsz=640 batch=16 project=biomecanica_proyecto name=modelo_ojalillos device=0
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ### **Descargo modelo entrenado**

# %%
from google.colab import files

# La ruta donde YOLO guarda el mejor modelo del entrenamiento
ruta_modelo = '/content/runs/pose/biomecanica_proyecto/modelo_ojalillos'

# Descargar el archivo a tu computadora local
files.download(ruta_modelo)
print("Descargando best.pt... ¡Guárdalo bien en tu PC local!")
# Out:
# Descargando best.pt... ¡Guárdalo bien en tu PC local!
