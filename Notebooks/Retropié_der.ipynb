# %% [markdown]
# #**Entrenamiento red neuronal para retropié derecho**

# %%
# Instalamos la librería oficial de YOLO
# !pip install -q ultralytics

# Verificamos que PyTorch esté detectando la GPU correctamente
import torch
if torch.cuda.is_available():
    print(f"¡Excelente! GPU detectada: {torch.cuda.get_device_name(0)}")
else:
    print("ERROR: No se detectó GPU.")
# Out:
# ¡Excelente! GPU detectada: NVIDIA L4

# %%
# Descomprimir archivo de base de datos
# !unzip -q /content/dataset_retropie_der.zip -d /content/

# %%
import yaml

# Estructura de puntos (pi1, pi2, p3) = 3 keypoints
data = {
    'path': '/content/dataset_retropie_der', # Ruta base absoluta en Colab
    'train': 'images/train',
    'val': 'images/val',
    'names': {0: 'pierna-d'},
    'kpt_shape': [4, 3] # 4 keypoints, 3 dimensiones (x, y, visibilidad)
}

# Guardamos el archivo
with open('/content/data.yaml', 'w') as f:
    yaml.dump(data, f)

print("Archivo data.yaml creado correctamente.")
# Out:
# Archivo data.yaml creado correctamente.

# %%
import os
import glob
from PIL import Image, ImageFile

# Obligamos a PIL a leer los archivos aunque les falte el marcador final
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Buscamos absolutamente todas las imágenes en tu dataset de Colab
dataset_dir = '/content/dataset_retropie_der/images'
imagenes = glob.glob(f"{dataset_dir}/**/*.png", recursive=True) + glob.glob(f"{dataset_dir}/**/*.jpg", recursive=True)

print(f"Iniciando reconstrucción de {len(imagenes)} imágenes...")
reparadas = 0

for img_path in imagenes:
    try:
        # Abrimos la imagen (PIL ignora el error gracias a la variable de arriba)
        img = Image.open(img_path)
        img.load() # Forzamos la decodificación completa en RAM

        # Al guardarla sobre sí misma, Python escribe un archivo 100% sano desde cero
        img.save(img_path)
        reparadas += 1
    except Exception as e:
        print(f"Error en {img_path}: {e}")

print(f"Se reescribieron con éxito {reparadas} imágenes.")
# Out:
# Iniciando reconstrucción de 2105 imágenes...
# Se reescribieron con éxito 2105 imágenes.

# %% [markdown]
# ###**Entrenamiento**
# * Modelo: Yolov8m
# * Epocas: 50
# * Batch: 8

# %%
# !yolo pose train data=/content/data.yaml model=yolov8m-pose.pt epochs=50 imgsz=1024 batch=8 patience=30 project=biomecanica_retropie_der name=modelo_tmRetroPieDer_unificado workers=8 device=0 fliplr=0.0
# Out:
# Ultralytics 8.4.78 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=modelo_tmRetroPieDer_unificado-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=biomecanica_retropie_der, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   4338487  ultralytics.nn.modules.head.Pose             [1, [4, 3], 16, None, [192, 384, 576]]
# YOLOv8m-pose summary: 185 layers, 26,419,111 parameters, 26,419,095 gradients, 81.2 GFLOPs
#
# Transferred 481/517 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3031.7±1694.3 MB/s, size: 971.3 KB)
# train: Scanning /content/dataset_retropie_der/labels/train... 1684 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1684/1684 770.7it/s 2.2s
# train: New cache created: /content/dataset_retropie_der/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3265.5±2193.8 MB/s, size: 1191.0 KB)
# val: Scanning /content/dataset_retropie_der/labels/val... 421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 421/421 427.8it/s 1.0s
# val: New cache created: /content/dataset_retropie_der/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 83 weight(decay=0.0), 93 weight(decay=0.0005), 92 bias(decay=0.0)
# Plotting labels to /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      7.54G      1.454     0.7959     0.3811      1.291      1.736          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.3it/s 1:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 4.7it/s 5.7s
#                    all        421        421      0.852      0.913      0.915      0.339      0.907      0.926      0.968      0.913
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       7.9G      1.246     0.3309      0.174     0.8455      1.565          6       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 4.9it/s 5.5s
#                    all        421        421      0.953      0.952      0.967      0.691      0.962      0.962      0.981      0.953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       7.9G      1.153     0.3178     0.1386     0.7606      1.508          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 4.9it/s 5.5s
#                    all        421        421       0.81       0.77      0.781      0.224      0.943      0.946      0.977      0.947
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        4/50       7.9G      1.089     0.2422      0.109     0.7225       1.44          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.5s
#                    all        421        421      0.967      0.968      0.979      0.788      0.976      0.978      0.992      0.972
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      7.91G      1.005     0.2136    0.09781      0.646      1.393          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.976      0.979      0.975      0.666      0.989      0.993      0.992      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      7.91G     0.9351     0.1758    0.07716      0.607      1.338          7       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.975      0.801      0.993      0.995      0.991      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      7.91G     0.9273      0.176    0.07118     0.5853      1.318          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.969      0.978      0.976      0.805      0.981       0.99      0.991      0.973
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      7.91G     0.8678     0.1528    0.07399     0.5484      1.278          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.985      0.988      0.977      0.841      0.988       0.99      0.988      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      7.91G     0.8156     0.1414    0.06197     0.5018      1.247          5       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.976      0.982      0.971      0.796      0.991      0.993      0.991      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      7.91G     0.8255     0.1341    0.05727     0.5018      1.241          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.983      0.976      0.764      0.995       0.99      0.991      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      7.91G      0.773      0.123    0.05451     0.4856      1.202          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.985      0.988      0.977      0.811      0.992      0.995      0.992      0.979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      7.91G     0.7636     0.1212    0.05534     0.4835      1.201          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.987      0.988      0.975      0.856      0.992      0.993      0.989      0.972
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      7.91G     0.7349     0.1135    0.05371     0.4475      1.183          5       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.864      0.993      0.993       0.99      0.973
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.91G     0.7353     0.1069    0.05421     0.4521      1.175          6       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.981      0.844      0.995      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      7.91G      0.694    0.09914    0.05181     0.4267      1.149          5       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.978      0.826      0.993      0.995      0.993      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      7.91G     0.7205     0.1056    0.05548     0.4284      1.164          7       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.978      0.871      0.995      0.995      0.992      0.979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      7.91G     0.6828     0.1126     0.0574     0.4072      1.147         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.977      0.871      0.995      0.995      0.991      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      7.91G     0.6449    0.09007    0.04431     0.3918      1.113         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.836      0.995      0.995      0.991      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      7.91G     0.6679    0.09333    0.04913      0.402      1.128          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.976      0.854      0.993      0.995      0.991      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      7.91G     0.6505    0.09135    0.05263     0.3891      1.116          7       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.875      0.995      0.995      0.991      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      7.91G      0.642     0.0856    0.04916     0.3802      1.111         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.979      0.871      0.993      0.995      0.993      0.981
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      7.91G     0.6285    0.07199    0.03957      0.373      1.091          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.977       0.88      0.995      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      7.91G     0.6289    0.07785    0.04586     0.3663      1.105          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.977      0.867      0.993      0.995      0.993      0.979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      7.91G     0.6006    0.08272    0.04096     0.3662      1.081         11       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.978       0.87      0.995      0.995      0.993      0.979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      7.91G     0.5873     0.0765     0.0393     0.3522      1.071         12       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.979      0.881      0.995      0.995      0.993       0.98
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      7.91G     0.5914    0.08012    0.04311     0.3497      1.084          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.985      0.988      0.976      0.875      0.993      0.995      0.991      0.979
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      7.91G     0.5973    0.07658    0.04057     0.3478      1.077         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.987      0.988      0.976      0.868      0.994      0.995      0.992      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      7.91G     0.5626    0.06893    0.04016      0.329      1.055         13       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.983      0.988      0.979      0.871      0.991      0.995      0.992       0.98
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      7.91G     0.5648     0.0735    0.04255     0.3383      1.062          9       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.986      0.977       0.87      0.995      0.995      0.993      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      7.91G     0.5504    0.07261    0.03539     0.3321      1.055          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.978      0.879      0.995      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      7.91G     0.5371    0.07213    0.04196     0.3329      1.039         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.987      0.988      0.978      0.887      0.995      0.995      0.992      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      7.91G     0.5523    0.06143    0.03677     0.3324      1.055         13       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.979      0.877      0.992      0.993      0.991      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      7.91G     0.5337    0.05788    0.03546     0.3152      1.038         12       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.1it/s 5.3s
#                    all        421        421      0.986      0.988      0.977       0.87       0.99      0.993      0.991      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      7.91G     0.5277    0.05941    0.03475     0.3141       1.03          6       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.893      0.995      0.995      0.992      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      7.91G     0.5177     0.0587    0.03825     0.3142      1.027          5       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.977      0.894      0.995      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      7.91G     0.4964    0.05443    0.03588     0.2991      1.012         11       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.976      0.905      0.995      0.995      0.991      0.976
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      7.91G     0.5012    0.05406    0.03305     0.2989      1.011         10       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.886      0.995      0.995      0.992      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      7.91G        0.5    0.05339    0.03651     0.2944      1.014          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.987      0.988      0.976      0.892      0.995      0.995      0.991      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      7.91G     0.4935    0.05064    0.03361     0.2957      1.015          5       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.976      0.899      0.993      0.993       0.99      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      7.91G     0.4804    0.05222    0.03097     0.2844      1.003          8       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.987      0.988      0.974      0.885      0.994      0.995      0.991      0.974
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      7.91G      0.385     0.0398   0.001966     0.2194     0.9555          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.977      0.901      0.993      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      7.91G     0.3579    0.03755   0.001191     0.2095     0.9353          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.978      0.901      0.993      0.993      0.991      0.978
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      7.91G     0.3456    0.03548  0.0007946      0.203     0.9302          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.904      0.993      0.993      0.989      0.976
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      7.91G      0.344    0.03281   0.000713     0.1987     0.9282          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.986      0.988      0.977      0.897      0.993      0.995      0.992      0.977
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      7.91G     0.3251    0.03096  0.0006858      0.191     0.9164          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.904      0.995      0.995      0.992      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      7.91G     0.3136     0.0292  0.0005862     0.1847       0.91          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.975      0.906      0.995      0.995      0.991      0.975
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      7.91G     0.3098    0.02981   0.000493     0.1844     0.9037          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.905      0.995      0.995      0.991      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      7.91G     0.2959    0.02861  0.0004645      0.177     0.8918          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.897      0.995      0.995      0.991      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      7.91G     0.2923    0.02899  0.0004483     0.1726     0.8935          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.907      0.993      0.993      0.988      0.974
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      7.91G     0.2827    0.02701  0.0004246     0.1695     0.8936          4       1024: 100% ━━━━━━━━━━━━ 211/211 2.6it/s 1:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all        421        421      0.988      0.988      0.974      0.902      0.995      0.995      0.991      0.974
#
# 50 epochs completed in 1.231 hours.
# Optimizer stripped from /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2/weights/last.pt, 53.2MB
# Optimizer stripped from /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2/weights/best.pt, 53.2MB
#
# Validating /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2/weights/best.pt...
# Ultralytics 8.4.78 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# YOLOv8m-pose summary (fused): 102 layers, 26,402,263 parameters, 0 gradients, 80.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 4.7it/s 5.8s
#                    all        421        421      0.988      0.988      0.976      0.905      0.995      0.995      0.991      0.976
# Speed: 0.3ms preprocess, 7.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/pose/biomecanica_retropie_der/modelo_tmRetroPieDer_unificado-2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
